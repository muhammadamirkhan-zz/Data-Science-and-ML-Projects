# %% [markdown]
# # Language Classification with Naive Bayes in Python

# %% [markdown]
# ## Recommended Prerequisites for Successful Completion
# * Intermediate level understanding of Python 3+ (e.g. list and dictionary comprehension)
# * Basics of machine learning (e.g. the distinction between training and validation data)
# * Mathematical probability (e.g. understanding Bayes' Theorem at a basic level)

# %%
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import numpy as np
import string

from collections import defaultdict

from sklearn.metrics import f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

import joblib
import pickle as pkl

from helper_code import *

# %% [markdown]
# ## [Slovak Wikipedia Entry](https://sk.wikipedia.org/wiki/Jazveč%C3%ADk)
# Mnohí ľudia, ktorí vidia na ulici jazvečíka s podlhovastým telom vôbec nevedia o tom, že tento malý štvornohý a veľmi obľúbený spoločník je pri dobrom výcviku obratným, vynikajúcim a spoľahlivým poľovným psom. Ako poľovný pes je mnohostranne využiteľný, okrem iného ako durič na brlohárenie. Králičí jazvečík sa dokáže obratne pohybovať v králičej nore. S inými psami a deťmi si nie vždy rozumie.
#
# ## [Czech Wikipedia Entry](https://cs.wikipedia.org/wiki/Jezevč%C3%ADk)
# Úplně první zmínky o psech podobných dnešním jezevčíkům nacházíme až ve Starém Egyptě, kde jsou vyobrazeni na soškách a rytinách krátkonozí psi s dlouhým hřbetem a krátkou srstí. Jednalo se ale o neustálený typ bez ustáleného jména. Další zmínky o jezevčících nacházíme až ve 14 - 15. století. Jedná se o psa, který se nejvíce podobá dnešnímu typu hladkosrstého standardního jezevčíka.
#
#
# ## [English Wikipedia Entry](https://en.wikipedia.org/wiki/Dachshund)
# While classified in the hound group or scent hound group in the United States and Great Britain, the breed has its own group in the countries which belong to the Fédération Cynologique Internationale (World Canine Federation). Many dachshunds, especially the wire-haired subtype, may exhibit behavior and appearance that are similar to that of the terrier group of dogs.

# %% [markdown]
# <a id='task1'></a>
# # Task 1: Data Exploration and Visualization

# %%
def open_file(filename):
    with open(filename, 'r') as f:
        data = f.readlines()
    return data

# %%
data_raw = {}
data_raw['sk'] = open_file('train_sentences.sk')
data_raw['cs'] = open_file('train_sentences.cs')
data_raw['en'] = open_file(train_sentences.en')

# %%
def show_statistics(data):
    for language, sentences in data.items():
        
        number_of_sentences = 0
        number_of_words = 0
        number_of_unique_words = 0
        sample_extract = ''
        
        # take a few minutes to try populate these variables
        
        # here is a hint -- word_list breaks the collections of sentences into a list of words
        word_list = ' '.join(sentences).split()
        number_of_words = len(word_list)
        number_of_sentences = len(sentences)
        number_of_unique_words = len(set(word_list))
        sample_extract = ' '.join(word_list[0:7])
        
        print(f'Language: {language}')
        print('-----------------------')
        print(f'Number of sentences\t:\t {number_of_sentences}')
        print(f'Number of words\t\t:\t {number_of_words}')
        print(f'Number of unique words\t:\t {number_of_unique_words}')
        print(f'Sample extract\t\t:\t {sample_extract}...\n')

# %%
show_statistics(data_raw)
# Out:
# Language: sk
# -----------------------
# Number of sentences	:	 100
# Number of words		:	 2016
# Number of unique words	:	 1322
# Sample extract		:	 Pán de Grandes Pascual jasne vysvetlil, aká...
#
# Language: cs
# -----------------------
# Number of sentences	:	 10
# Number of words		:	 158
# Number of unique words	:	 141
# Sample extract		:	 Upozorňujeme, že jejím cílem je šetřit penězi...
#
# Language: en
# -----------------------
# Number of sentences	:	 100
# Number of words		:	 2381
# Number of unique words	:	 1037
# Sample extract		:	 I can understand your approach a little...

# %% [markdown]
# <a id='task2'></a>
# # Task 2: Data Cleaning and Preprocessing

# %%
def preprocess(text):
    '''
    Removes punctuation and digits from a string, and converts all characters to lowercase. 
    Also clears all \n and hyphens (splits hyphenated words into two words).
    
    '''
    
    preprocessed_text = text
    preprocessed_text = text.lower().replace('-',' ')
    translation_table = str.maketrans('\n',' ',string.punctuation+string.digits)
    preprocessed_text = preprocessed_text.translate(translation_table)
    
    return preprocessed_text

# %%
data_preprocessed = {k: [preprocess(sentence) for sentence in v] for k,v in data_raw.items()}

# %%
show_statistics(data_preprocessed)
# Out:
# Language: sk
# -----------------------
# Number of sentences	:	 100
# Number of words		:	 1996
# Number of unique words	:	 1207
# Sample extract		:	 pán de grandes pascual jasne vysvetlil aká...
#
# Language: cs
# -----------------------
# Number of sentences	:	 10
# Number of words		:	 155
# Number of unique words	:	 133
# Sample extract		:	 upozorňujeme že jejím cílem je šetřit penězi...
#
# Language: en
# -----------------------
# Number of sentences	:	 100
# Number of words		:	 2366
# Number of unique words	:	 904
# Sample extract		:	 i can understand your approach a little...

# %% [markdown]
# <a id='task3'></a>
# # Task 3: The Naive Bayes Model

# %% [markdown]
# **Bayes' Theorem**
#
# \begin{equation}
# P(A | B)=\frac{P(B | A) \times P(A)}{P(B)}
# \end{equation}
#
# Now, let's translate this theory into our specific problem. In our case, where we want to categorise a sentence `my name is Ari` into one of `sk`, `cs`, or `en`, the following are the probabilities we want to determine.
#
# \begin{equation}
# P(\text {sk} | \text {my name is Ari})=\frac{P(\text {my name is Ari} | \text {sk}) \times P(\text {sk})}{P(\text {my name is Ari})}
# \end{equation}
#
# \begin{equation}
# P(\text {cs} | \text {my name is Ari})=\frac{P(\text {my name is Ari} | \text {cs}) \times P(\text {cs})}{P(\text {my name is Ari})}
# \end{equation}
#
# \begin{equation}
# P(\text {en} | \text {my name is Ari})=\frac{P(\text {my name is Ari} | \text {en}) \times P(\text {en})}{P(\text {my name is Ari})}
# \end{equation}

# %% [markdown]
# ## Unseen Data
#
# Since we assume conditional independence across our features, our numerator term for any of the above equations can be broken into the following.
#
# \begin{equation}
# P(\text {my name is Ari} | \text {en}) = P(\text {my} | \text {en}) \times P(\text {name} | \text {en}) \times P(\text {is} | \text {en}) \times P(\text {Ari} | \text {en})
# \end{equation}

# %% [markdown]
# ## Vectorizing Training Data

# %% [markdown]
# |Sentence   	||   my   	| is 	| I 	| love 	| name 	| it 	| Ari 	|
# |-----------------	||:------:	|:--:	|:-:	|:----:	|:----:	|:--------:	|:---:	|
# | my name is Ari  	||    1   	|  1 	| 0 	|   0  	|   1  	|     0    	|  1  	|
# | I love it 	||    0   	|  0 	| 1 	|   1  	|   0  	|     1    	|  0  	|

# %%
y_sentences, y_train = [],[]
for k,v in data_preprocessed.items():
    for sentence in v:
        y_sentences.append(sentence)
        y_train.append(k)

# %%
vectorizer = CountVectorizer()

# %%
X_train = vectorizer.fit_transform(y_sentences)

# %% [markdown]
# ## Initializing Model Parameters and Training

# %%
naive_classifier = MultinomialNB()
naive_classifier.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Vectorizing Validation Data and Evaluating Model

# %%
data_validation = dict()

data_validation['sk'] = open_file('val_sentences.sk')
data_validation['cs'] = open_file('val_sentences.cs')
data_validation['en'] = open_file('val_sentences.en')

# %%
data_validation_preprocessed = {k: [preprocess(sentence) for sentence in v] for k,v in data_validation.items()}

# %%
sentences_val, y_val = [],[]
for k,v in data_validation_preprocessed.items():
    for sentence in v:
        sentences_val.append(sentence)
        y_val.append(k)

# %%
X_val = vectorizer.transform(sentences_val)

# %%
predictions = naive_classifier.predict(X_val)

# %%
plot_confusion_matrix(y_val, predictions, ['sk','cs','en'])

# %%
f1_score(y_val,predictions,average='weighted')
# Out:
# 0.6149824401040264

# %% [markdown]
# <a id='task4'></a>
# # Task 4: Simple Adjustments and Highlighting Model Shortcomings

# %%
naive_classifier_ennhanced = MultinomialNB(alpha=0.1, fit_prior=False)

naive_classifier_ennhanced.fit(X_train,y_train)
new_predictions = naive_classifier_ennhanced.predict(X_val)

plot_confusion_matrix(y_val,new_predictions,['sk','cs','en'])
# We expect great improvemens in the confusion matrix

# %%
f1_score(y_val,new_predictions,average='weighted')
# Again we ecpect huge improvements in F1 Score as well
# Out:
# 0.874421671678189

# %%
# We improved by about 26% which is a huge improvement from our previous F1 score

# %% [markdown]
# <a id='task5'></a>
# # Task 5: Using Subwords to Shift Perspective

# %% [markdown]
# **Dummy Dataset**
#
# playing ; eating ; play ; reads ; tea
#
# **Step 1**
#
# Break each word into characters
#
# playing > p l a y i n g
#
#
# **Step 2**
#
# Find common character sequences
#
# ea, ing, play
#
# **Step 3**
#
# Convert dataset using these subwords into
#
# play ing ; ea t ing ; play ; r ea d s ; t ea

# %%
# taken from https://arxiv.org/abs/1508.07909

import re, collections
def get_stats(vocab):
    pairs = collections.defaultdict(int) 
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i],symbols[i+1]] += freq 
    return pairs

def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word] 
    return v_out

# %%
def get_vocab(data):

    words = []
    for sentence in data:
        words.extend(sentence.split())
        
    vocab = defaultdict(int)
    for word in words:
        vocab[' '.join(word)] += 1
        
    return vocab

# %%
vocab = get_vocab(y_sentences)

# %%
# also taken from original paper
for i in range(100):
    pairs = get_stats(vocab)
    best = max(pairs, key=pairs.get) 
    vocab = merge_vocab(best, vocab)

# %%
merges = defaultdict(int)
for k, v in vocab.items():
    for subword in k.split():
        if len(subword) >= 2:
            merges[subword] += v

# %%
merge_ordered = sorted(merges, key=merges.get, reverse=True)

# %%
pkl.dump(merge_ordered, open('Data/Auxiliary/merge_ordered.pkl', 'wb'))

# %%
def split_into_subwords(text):
    merges = pkl.load(open('Data/Auxiliary/merge_ordered.pkl', 'rb'))
    subwords = []
    for word in text.split():
        for subword in merges:
            subword_count = word.count(subword)
            if subword_count > 0:
                word = word.replace(subword, ' ')
                subwords.extend([subword]*subword_count)
    return ' '.join(subwords)

# %%
data_preprocessed_subwords = {k: [split_into_subwords(sentence) for sentence in v] for k,v in data_preprocessed.items()}

# %%
data_preprocessed_subwords
# Out:
# {'sk': ['de an de al as ne as ve li vy ak je an pr ho no in ie de er or mu re vy ad že in ia de to me po al re la bo it ia le al aj že al na na me st ov ie pr',
#   'by ke me sa po ne li si ne mo né ak by me li mo ia do en',
#   'il že ci bu de sa st ch or vý re an né ve ci',
#   'ed ie by sa mo lo ať že de al bo po te vo ct',
#   'je om je ie en ov ať ve ak la st ie st me ne pr áv st ed at ne po pr ce re st ch ch ia ve by sa sk ur om ar on po li sk in ie or re po né na ne pr áv po it ic re la né en ie ho no',
#   'na ie ia do to to ie je ne ia or mi it le by en sk ed li av pr at re ia at po al ov pr',
#   'an re ed aj re ed ro ar so st an ov il ro ie st la ro by vý it ov ne en er ie ie om is ie en ov ch sk ov ly be to ho by sa li na ia vy na st ra',
#   'to po ia av ak ie je st to ne do ne pr an ov or mu po ia de om sk',
#   'pr vo aj en an re ed aj is ia ro vý ch mo ov le te mi li re en ed že re po né pr av že re po né il né po ia av to by sa li mo st ať in po mi že je re po il en ra',
#   'ne me mu vo áv vy ať ne il an áv vy ch pr áv re is ov',
#   'en po ch to ch er ch ic je ch do',
#   'pr pr je me av sa na ch ly at áv st po it to is pr li pe ro me to en an ak st ch as vo no re ch ve in an ci al na or en po ne ci ov ne il st om no',
#   'en an re ed aj ie om ia st an al er ed',
#   'je ce ur aj po né že ed me so en al mi mi',
#   'bo to ro ch ce ov or je to an en or ia na no bu',
#   'to pr áv on do pr áv en ie be pe re ve re la sa mo né re st no ri sa že er to mu že sa že st ať ic ke',
#   'to an it no ed je no mo on do ia pr mo st je av le st to je po st le en ro om pr áv er om ie ak re en ie',
#   'že me ic ov ia ar on ro sk ia le be on pr ve en na vo be ia il ie om ne ia ed vy ro li né or ia il an ch me an ov ia at ov on',
#   'to to ch sa an en ov ie vy to ch je or to ro en lo mu ia it ia mi st il so st is ne lo áv',
#   'al ie vo re po né ho do ro ra na an ch ed ov',
#   'ch ce by me li bo ed mi an ov ia vy en ci by me st no bu al er ov ov ou st in ve ci',
#   'na in bo ro en re po je me bu an ia do in ne im',
#   'to ro ov',
#   'sk at ci ro ho lo na de la re re to ro sk an ia ie li',
#   'ne ak en ed av že po ed ať to že lo bo st en st an en ov ie re to ro sa ov or il že po ro me de bu ie mu ov ra in an or in sk om na st to po en om sk te in mi ov mi ne me',
#   'ed om sk ur en ar la te',
#   'na ov ce en ie ho no ne as sk ad ho do je is ro pr',
#   'to er ic je ak an er re ov na ch ve st to ro ri er ne ie ad na ly to by to mo lo ať na po ro al ch re st ch po ov to vy aj po ne ov en ie ia an po ro en ia ar an pr ou áv in en ce li te re to sa že ci to to ov ho st mu bu po ne pr de do av li ro om to vy aj en ia ia ar le ho sk do ad to ro ie on en ia ia ar',
#   'ia na',
#   'st ar en er ci po it ov to te st le ne li na st po ch ro ov le ro ov ch ce ie aj ro lo to ve',
#   'ie pr na to mu me sa an ov bu ne lo in it ed ne on ci po pr ce to sa in ro la st ch at ch vo ro ch ia de sa al do ho na re bo re ch ch re at to ia mo by po ro na ro ne al ov',
#   'je re že ia de ra mo na in ra po je ra ro ce se ie on li so',
#   'in mi ov mi sk ur an vo po ie st po ed no pr en be pe to ho by in en li mo ne lo bo be en ed po ať vo in er at sk by sa vo je vo ro ne in ra li ak om',
#   'po on na ke ro ov as om in om ar že re po je me bu st to do né ro je ho ci re po ne je me bu ro je na to en on re me en en ro ch ch om on ic to',
#   'te že sa ed ie av en ed ie no st en pr áv ov av vý re ro ak in om',
#   'ne do to en ro ce ia st al ro sk',
#   'to to vo sa en re ed ci aj ie om me že an it né in sk by vo ch en ch sk to ch al vy ať ho vý ne ci so po ci mo st ro no st to pr le re to ho aj ho vý it ch so ro ov ra ch ci mo ro vo re ov to ch ch pr aj',
#   'sk ur is ia om ed no áv on la do po ro ie pr sk an ia ia do ch sk pr áv na an ke',
#   'ak st po al ed ch ce ho aj sa an sk že bu ia na vy ad ať ne ie na ho vý ne pr áv st en po ie av al bo po ed né ov in an om er ar',
#   'je me il sa in om ci in an an ov ia st no ro ov na ch ce lo re ch on ro ov sk ur st in ne ve an',
#   'is ia om na aj ve mi po ne or ed je ro je ov ly or re st',
#   'to en áv en ia ia ar je ed om vý st ia do ho sk ur en ar la en ur is om re ie vo vy ne pr ho áv áv po sk sk ur an om je en er na sk ur ro er ic an er ch pr im er ch no',
#   'in ul de re ed ne na il ar sk po it ic ke st an de an or pr ve te áv en ov sk al vy ar sk in en st to om ic in ia ic',
#   'po ne na sa it ro an na ro je',
#   'on ne ia pr st st in er an ch ve ne la bo st in er ou an ch ve si že al ov ne pr an en ak ri st ov ne ce an ce ri',
#   'ro ce se ro by vý ro ia sa ro je vy ov en ie st vo no re to aj ro né st po no lo in ve je st in ov ve ať pr ve do to to ch te no',
#   'ak ch ce me st by to to ak al po al ov ne ra de bu re po né an ie on st an ro ch re ch la ov or ov or po ho sk že',
#   'pr an ov do sa ho do po me st ne ou po po ro en ar la',
#   'en re ed ci aj po je že st je sk ur ho an it ne po ci mo en ia ro ov by re me sa mo st al ro ov ne te ro po ci mo in ra to na aj re po bu',
#   'om ve mi že sa ne me ho na om bu vo vý er ne ho na je st ce sk ur',
#   'je re to st ne pr né re lo ne pr áv to je aj st ov do',
#   'áv na en al ie in sk ak ie je',
#   'ch ce by om ve li vy re om to er ne po de ho do an sk re ed om ct to ed lo vy aj pr ch ce om to po ed ať ne ne or re by om st al pr me to ov il mo om ch li ur st en ie ia ia do to te ho do al bo ne ra re né vy ad re om po na ly',
#   'in ak de bu ať ed vý ne ho né an ov ia as en on ci mo in ro',
#   'is ak je at ul ed vý re re',
#   'ch ce la by om ie ie že is ia om al pr ve re at na en ie be pe at ho né en ia ia an ch al ov vo st no be en ie po ia de st an ov ie ra ie',
#   'ie by om ch ce ra že po je ho né ov pr ať do ch ci bu ov áv is ie om pr né pr av to ia mo po ie sk po ci mo aj po po ro ho no st ch ia la po om ly en ne ch ho vý ro ch pr en po mi al ou ro ou lo ch ch na ci aj sa st in ne at ho ad is ad ed ch no to ne aj st an en ov it ri',
#   'ov te mi vy ad ri an sk mu re ed ct je mo an ie an an ov ie or re ie on ur ro al er ov im ro ch be ak lo to re ed vo ct re al',
#   'en ed',
#   'ne me že as to po to ou me al bo ov as mi la mi an en er er ov ch li al de sa me as že ie ve le te ke pr do vy by al is ie pr vo ie om en er mi ly na vo né re st ro ie',
#   'to to an po ie de ra lo bo ne ia or mi it le is ad po ia sk na ne pr áv st to en ci by li mo ov at ať je vo pr áv is ia ce an ou ce ou ra vo st st ro ou li vo pr ak to al on sk ur or',
#   'al is ov pr ov pr ci bu ať ie ak no mo ie pr si je vo in ro ci en ho sk st po to om so sa po po je en ed ie no in ro be st en po ia av sa na ak ro ia ly ne be pe ro ce to st to sk no je',
#   'de en an re ed aj er že by st an ne to no je or ne ie as že re st al by st to ne do in at or',
#   'ak ie te sk ur en ar la sa st ch pr ať en ne ie de ho do ct pr om to ak st le vo áv vy na né po ne je aj ed na mi an mi na to al an ne je ed na no as or si re to že by re po mo lo by ke me al ed ov áv vy sa as po ve om om bo',
#   'no re po ch ch re st it ov av st ne ve',
#   'pr áv je ra to le ne le ho an ed ia áv vy bo ro in is ci im en re ov st la st pr st an me to la ov ch pr en po mi ar ro ho né si an ia de áv',
#   'na si al ov ch je vo ne ul ie ra ho no',
#   'mu sa re to vy al on do ce ov vo vý en po ci',
#   'om ad na to že do in ho ul ro sa po it ic st an ov ia re ie de ul to ro ri ne re ie ul al ov ch vy st om av st po ho ov te mi en po pr že pr ve to ie po it st li vy do ve ke ch by do st er ov no po ne er mi st ra st po ho an ov ia bo sa in po ch sk ra st po no lo to ro ia li do is li mi',
#   'om ak an sk la že po ne lo ho do te to ch li li an po ci ho sk ur en ar la to en ar la ra ak na an ch ia as ad ak al li bo as ur le ie in ou sk pe de in ou sk er ov li',
#   'po ne na sa ne že na je se ro po ia na de la po ov an la la po ro la al né mu re st né mu an on ie st ov ie er ov ch il mi ov ch to an on de to si po al pr na vý al',
#   'ro ve sa st to je ro že by me sa al ne st vy av ri že en sk st ia vy ch',
#   'sk to en ro ke je me la ro ie vý ur an ra sa en ov sk st al en om ro',
#   'po pr me en po ne ed mi ne ho ro ce ro po it ic ke st an ak',
#   'ov at re an po ov na to ro me al ov pr ho no ro ov st do st at no ov om om le vo do',
#   're to me vy sk bo or by al on vy an po ia it ho né so pr vo aj re sk pr áv bo',
#   'en na ia ia re om li st ov ch lo bo an en ch',
#   'to pr áv to že re ve né ie ra je ne né vy re po lo né ro do',
#   'ov te mi er re to ie st to ia le to st li or áv en ne ia to sa po al pr ve',
#   're ne ak ak pr de la by st al re sk ať no mo ia pr at er ce an ch re om ri po ro ia',
#   'or vý re ro vo na ho re im an po ia áv pr áv po ed ch li no vý ra by li se mu ro na né po ie or po áv ať pr áv po ed ch li no vý ra',
#   'ne om je me as to to en ne ie de že sa ch ia na ov st ch ce ci le te ke pr ve do po ia de as st av ve al er ia li ie st la pr do vy st ra po ch le te st po no lo',
#   'sk je ne ch né po ia ať ak by vo',
#   'je to pr na ov or vý re in ra to sa ia na ed pr av an ov ie sk la to ch vý ak as an ov ia do ch ke to ia mu je ro na ia na ve te la so te ie an it ne',
#   'de en re ed po al ne ia om ov re to by om ie la ro ed ur ie al re to že by om re ed ch na ov le an po ov ch ce la po or na ro re de la',
#   'li mo me re me sa mo to to mu to se pr de li ia pe ak to al ov na st ov ia de at ci no ic mo so ke st an al je do že re li bo to to áv po ro en en vy po as ne ak st ro ed ri',
#   'je ho en ov ia al ne av do ra ro ne pr ce',
#   'ne om im sa vý it mu na is ch si že st an ie to mu bo st en vy av je ne vý po it ho ic er ch ar ak',
#   'sa mo né st en po ie av an mi en na in is ci im er ov no is ie pr ne pr re st om ro na re st in',
#   'po to de bu ed ov na ať re ia on se te ri po sk re ed om ct na mu ra st né st ie ar re to ou as de bu in se in or ci st st st ro li vo by so ia ce al er ov ou im ro ch ou in mi en ia de mi',
#   'po le sk',
#   're to er že is ia om de bu en po de bu to te st la st po po ať to ed om re to že re st né pr vo ie je st ro om en do né mu po it al po ed st ro ed om ri an ov vy pr áv',
#   'in ul ro se te ri is ia om re la lo sk ur mu en ar la de ra pr áv ia ho no st re to la bo st po at re an je ho to no',
#   'en re ed ci aj en an an po ne en an po ci om ve mi že že po ed ať že pr áv en ie is ie om po po je pr vý or st no mo po it re re ia at to st an ov je',
#   'ak de bu to po it re sk ur pr at ne me vy sa ia ak pr an at st an ch vo do an ch ch ed ov sk ur',
#   'ie pr na ke it ke to la bo pr ve re an ov ad to te po it ke to ro sa st to je om al na re en ed že to sa ed il st in lo by al re ať pr ch na ro ch aj st no bu',
#   'po le sk',
#   'la mo by áv ať ve mi po it lo pr ch ie an ia vy st at bo po ch ho sk po it ch ic ch ho ed ro mi in ra mi ur in at sk er',
#   'me mu sa er ať to sk om so ak st na me to na re ch ov ch pr st ch ie',
#   'ne ur re or ne me že re al ov ať be ov ch po ov re to že ia ie ch st vo as pr na ov ov pr né st ie by mo lo or vy re ne ci so po ne je'],
#  'cs': ['po je me or že je le je it en st in at ad je vý',
#   'ce la en te že ne ro it lo de an al er st do áv',
#   'pr ci na to pr áv by lo ch by al ov pr pr áv to to st st ed vo av',
#   'ne na po po en it ed no ov de to se en er ic st la to ak ov pr ve an ou ho do po it',
#   'to je',
#   'to to ho is ed ce la ou as po mi an en er',
#   'ro pr av je en on',
#   'ed na mu vý er st ve ic ro ro sk st po ho je né st an it ch te ic ch se st ve mi ro vý mu en le ch je ho vo né po bu na it',
#   'ro ce je to po by ly to to ho on vo st ro ed la by it vy ov ce st on li mi ur an ov vý on li mi ur',
#   've st en ou vy ch by ch la en it áv an pr vo aj an sk or er po do na ed le ra of ci le né vý st in no no or st in no ne le né vý er se ci it ar li so me en er ce mi on áv vy in ro ch'],
#  'en': ['an st an er ou ro ch it le it',
#   'er me of en ia ar se in te',
#   'the st en is of in re en le se ro me ra',
#   'en al is on de at is er an po im or st in le en er',
#   'it or aj re ed je ct the se on so an is to st in ia bo',
#   'ro at the st ar of the ar the en ne lo at re ed ch le wh the it de ic as ro in er ou er me st at',
#   'we re as ou on le ra er me no in po ro je ct de or in the st in is ra en ia ho or in is on at im on an ro',
#   'en or ne in it se in te',
#   'in it on ad it ie om mu ou be po ed th bo in an al ci ly an by ci ic pe on so on the re al on le ve in er or to ro ve im the le ve of al om mu er ce',
#   'is th in de al al er om ci as pe ct of it on at lo as we as the al le al on ra ct an in in an re st ct of the re it on at lo de mo at th il re en at th st le an er ov ce de mo is in to ce la',
#   're re the it is me at th we st ar in ct is ve de ly an le ve ct ly on to er ou is th ne er st ro at ic or of is er ro in ro pe',
#   'the in on at te ch wh we ar so ch mu ou st mu no st on si of ou in en is it st ch as ri st er st ch as an so or th in ou in en er ar an ch in an at te to om at mo li mu an mi im or is th ou re ul in lo ss of ou al ur ul en it',
#   'it is st an is it no in an in ch wh al er on en it is in be al ou je ly ed ar an en it the is re ed ar as the me ri it is at th om le pe ou le th ly ss se to st ro de the en it of the st in it on ch wh de the at wh the re in en the the ed on at the re re the',
#   're re the on at at ul the ou of to on it en ce an er ce or in an re it the po ur ra te it re ar to al is on on si',
#   'bu at wh en ed in the ar en be we an en wh the ro as in it an ch ri an is re ce de or ss re we in ur the po ie li as at th st al mo on li il re we re ed at',
#   'as en be er le ad in the ne ia on an as al so st en ed li to the the ro',
#   'en it st mu be er re ul en wh in ch as ur in ed ic in on se be re the an ch ce of in al ed si in ed ic re in as by to',
#   'we ve no re de si to ke in al to ic al',
#   'in ra ic in le pe in in re ch il or ne mo or re le as or an or is re in in as it ch ar at th as se',
#   'in al ly ou to on de re en si ou li ke to en on ou st in en ce si on the on at li an en on le at im of re me as at th ve re al ad en be an ed ou be it the st in it te or al it the re en on en ce or the ul on at li of st in re ve ct so at th we an ak the an on at ci of en om an the al er on an al ro on si en il ul the en al al of ou in it ia ve an the st at it se',
#   'the re en of the to by ce or an the ar po er is re at',
#   'is th ct po an the in an er in ar ar ic ul ch wh ve en be ed ne le ct in re en ar an no or the in of is th re po',
#   'it re en si is er om on si st in er ie la an en en le ro th is th ne re on at ul on le te ro ct in la be ch wh we il te vo on in en ar to ro or ro pe il re ch an ve je ct it as en be in ur or ar',
#   'at wh we re re ur ly in en er re en si is no in in on ne ar mo is is in the on it is no en is is of ou in le re ur the ra it is is is of an er ov ce',
#   'en ov la an the ve in po ed ou at th the re po it il si or it ur se at th is to sa or st in is re se it on at in ra re st pr ar il im it the ra it ie ho',
#   'en er ce ro the st en as se ss of the al on na on ct an st on de at in pr ce ct at th it on on in the ve no re at to the in po at ch wh re me as to ro te mo en er en ci an be po ed',
#   'on is al be an th the is er om on si or is an er to the st on',
#   'it re al ly do lo li ke we on ly en on at to the re st in te of in an al ci st in it on to to la pe an to in bu ss',
#   'the ic as ho at th no ne er at wh the po it on or st at at the me of the on li ct is ne mu im ro st ce re en ed at th no se the in al er on na in al im ou ro te mo re pe ct or an ri ro ss ou or',
#   'wh do we ed ne it',
#   'ho pe at th the st an ri al er ed en er ov il on so in on so at th is ie at the in en ly we ro ed te ct an en ov in it or in st ia',
#   're er ov mo as in ed or at th ou is ed to ak pe on re je ct',
#   'we ve en be to at th it as no to na ve se at th it as no the ch ar le de le ul',
#   'ho pe ad is er om on si at th ou il be re in ur to the is om on si an at th in the ne en ia ar on se si ou il in ar or po al ro on ed ne le st ic in ie ur ch wh is er an po im or an al th re er or an is er le vo ro le in ou al th re st',
#   'it ad re en si en wh en ur to an is me en at as no re is ed by the an er ic on le te st in it as no se be of la of en is or is se of an al it bu st in ad the re il to me it on on no ve the ne mo to re st er is en at or the an ar',
#   're wh il mi ov ho sk or an to la ed le re er ed on ou st at at th the se in al st mu at st la be re ed the is the st at is it by the an si re en si to the an ro pe en ia ar il ak ce la er ou',
#   'we om we er on at en be we er me st at in in al de it the se ro le',
#   'is th is the en al ch in',
#   're the re no of to ak is th ci il ro on te ct ce or le st ar it or of',
#   're en si ou li ke to in on it the en ar ro ch pe st er on the re ar on at or the en en it an the en on st er in of in me ch wh as no ly ce ul ss',
#   'it is at th en wh in ne ia it ou we al no re wh we re',
#   'ou al so li ke to re st ss the an po ce im of re me as ch as the er on at ic of sk il al ro on si in in ra in en ve or re on at an the po it to in ne en er ce in the ce or la',
#   'the ro ce ed or te no an in of ch al it ch wh en ve it on at im of the it ur se re at at th the an on the re st is as il en ak in by the ed or ro te no',
#   'in li the er ie en be we the re en in ed vo in ve de lo ou le pe in en en ce de in ak on ct to st ou le pe in le av ed on at ar ly re in er as the an po ce im of al on at vo in in ra an re ce in do in in an ro pe al it me or ra or in in ra ch me the se re the in of as de at th it is an po im or to no at al on na le ve',
#   'ro at wh is the re ce en be we the st ne re po an the re on so at th ed lo',
#   'the is the it le at im al or re pe ct or in it or is in an er of in ur in to or of re er se in is on at im to the en de im of al ho se st ne ho en it ho er the me ri an se bu of an ro',
#   'the re ve ct ak in to er on on at si the ci ic pe al ci so st an ce ci of the in al er me st at',
#   'ho do the ch re en si as se ss to te vo in en ia ar it re ar to the an ro pe re ve at st ar ho an to ro te ct the ri on the in er ne',
#   'an po im re ro ss as en be de bu it is st il no en ou',
#   'ou al so li ke to on at at ul in ar ar ic ul ro ar an is er ce or is th re ro ed to ar or the re ar on at of the is on le at',
#   'the an ro pe on is on it',
#   'ou li ke to on at at ul is er me on is th po it ve re po',
#   'ou ly at th do no se re en ed or the re se be al the re al ly an po im is in er on the an ch to the re at ch as or le the to al le re ro ed ou re re the in en on of en on on',
#   'at wh re the al on na en er ov in it or',
#   'ou li ke to en on ne the ur in po at th as an po im in the de at re in ar the wh or no we ou te vo in ou av',
#   're en si an ro ia ou as in re ou ar the an om bu as re en ed er ve je ct re po of is it ie ct ro ch wh an be st is ed ho an po im is is on si is or the en it of the an ro pe on',
#   'the de at is ed lo',
#   'ed vo in ou av of it an er on si it to be en ce',
#   'it re en si ie la an en en le the in al pr ci on ct an ed or an in ly be po ed as re ar the ro th an ro ed or by the is on st at',
#   'is th po se an en ou or en al ch to the po al it ic st in the an ro pe on an the er me st at',
#   'the se st in en ve en ro po ar ul it er on an er ro al ke',
#   'ie la an en en le ou en ie ce ie la an en en le',
#   'in ce no is th is er at of po al it ic er on le me ad in al en om on ar ed ia la',
#   'the in ar re po is the st be le of is th ro ch',
#   'in the al in bu ss re re en ne ur is in be ed ar an an is ed ad by re at ic bu re in er ce an re er ov on at ul',
#   'it is er in of ou to en on is th',
#   'ou li ke to se the the ur ad it is th in the on te of at li ro on te ct an ho pe at th we an in on ce al the the or aj in om pe in to in is th re en',
#   'an to an th ou al so or in av er en er ou ly en the is om on si the po it il si or of st ra in av ur re mo in the bu or the st in an al',
#   'the in po at th we in th re an po im re al so en ed on in the re on so at th is re ur ly on the le',
#   'ar ar ic ly ul re st in ss is the an ed ou it ed li ce ss to re in er on at in ur in ar or in vo en wh in is ss al er en en',
#   've ro le it ur ke en wh lo at it ou be av to ar in er an en wh er on si pr re ou li re ed om re ed om of in on the an on po al it ic ie ar an ar il si is',
#   'is th is an en al ss ar of the it il to ce ne er me st at an al so to in re in in as st in ro pe on it en it',
#   'we ed ne to in in er an al ce ch wh il ar sa th bo the ri of en at ho re no re me ly er on to ro ss er ro re an al ce ss or al to al it re it it ar li so ed as re po it il si to re en al ci so an to al er ri ri on si an re pe ct or the in pr le ci of it ia si',
#   'it is an po im at th al the er me st at ur the re de la ve je ct th bo in ly an in al ly so at th le ve of en lo an it ro ct an be ed ch ie in ro pe',
#   're the is st ed se of the is of lo ss of it il lo',
#   'an ro pe re it ic ul is the st la ar of ou al ur ic ul po li at th is st il no re ed or an st il or on the in pr le ci of the er the ie the re mo ne mo ro se',
#   'bu it is al so or th in in po ou at th ou en ve de lo in the st on re ic ul an ro on ct as the er ak pe ve en ed on an al ra ic ly in er at ar we ve ra ro in lo at the an po ce im of ro on ct re ic ul in the in ve de lo or',
#   'al ou th it as re ur in the it ed st at ie er an er ic re to la re re en an st an ar we st mu al ar le om on le ss ro it an re en an ar il si en ci',
#   're en si the ct at th we ve ed vo po or is ro om on the is of at li an ch is er an po im',
#   'we re in ro re in in as ly er ed on ou the re ro ss of the is on de at at mo ro ce ss in ur ke',
#   'th ly the al le it ho of er ro an is on at or st mu be an ic si ly ro ed im',
#   'on ho se ho re er ce ly ed ch at to the it of the ar on ce ro ce ss ho ie ve be at th re ro ss is no re me as le so ly by de ra st st at ic ch wh re in en al ci ly st il to ou le ra av to ou er ar ro the ou th to the po on at ul',
#   'en on in om me at or the er so of the er ou ur en ss en al is on as ed ve il re the',
#   'the re po by to on is an at ur re po ch wh se ou the re as on ch wh is on le at an po li ou en on at to ro ve im the er on at of the in al er ar ke',
#   'do po al it ic re en re er to st re in ad re en or to re ar on at or an ar ly on se re in ad re en er the re ch re en si',
#   'om we is th an it an me we an al so be it the re ul',
#   'ad re en si ho pe at th ve re po ed to al the en om an ou li ke on ce in to an th al er me or the or of en en ou ra an al so to on at at ul ou ad re en si as the is er om on si as re al ad ne do or the an po im in it ia ve in im to ro ve in re st er or en ia ar an the is om on si',
#   'al we at th en we',
#   'the de at is ed lo',
#   'le wh er en ke to se al th in at it ro ed mo on st er ou in the an the we ve re er on at ou the ar bu al on at lo po ro ed in is th re po ch wh re er on si ly re er at an th the ur on li il po ro ed by the is om on si',
#   'sk il to be ie in er or to ke to the it li',
#   'of ou se the se is ro on st mu no re me ly st on er bu st mu al so be ed li in pr ce ct in st en on si an er ro ou th ro pe',
#   'an at th il ro de ch mu st er ro to an re st in ra ct to ar ou the st te ne me in re mo ed ro ri an re an er',
#   're en si of the an ro pe is om on si le me al so st ar by in on ve on al be of the is om on si ou st le ul on at mi ad re pe ct an it ar li so it the an se le pe',
#   'we re no en se ar in to the ro ce ss',
#   'as ne of the st le pe ro ou ro to it ne ss is th in it the it om te on en lo an al ci so an an th ou ar ly',
#   'we re in ct in it the pe of ou re ro ve at an we re re the pe ct the ou ci to do re po le si po al it ic it de at at th is ar il si to ou',
#   'an or do at an po al it ic is er pr on ed in av st ed er st ke ri',
#   'ou li ke on ce re mo to ak it it ar le at th the se of the se po we in in in ie ou re wh the an ro pe on as po ce li an it ar il ce or in er on at ch as st an an ia bo an the de at ic mo re li of on re re en st as ch mu of an er to ou is on si as to the le pe the ve se',
#   'at ul to en ia ar or at wh it as re al ad ne do an or at wh it il do in the re no at th it il is le at on the re of st ce an it ur se']}

# %%
data_train_subwords = []
for sentence in y_sentences:
    data_train_subwords.append(split_into_subwords(sentence))

# %%
data_val_subwords = []
for sentence in sentences_val:
    data_val_subwords.append(split_into_subwords(sentence))

# %%
vectorizer_sub = CountVectorizer()

# %%
X_train_sub = vectorizer_sub.fit_transform(data_train_subwords)
X_val_sub = vectorizer_sub.transform(data_val_subwords)

# %%
naive_classifier_sub = MultinomialNB(alpha=0.9,fit_prior=False)
naive_classifier_sub.fit(X_train_sub,y_train)
predictions_sub = naive_classifier_sub.predict(X_val_sub)

# %%
plot_confusion_matrix(y_val,predictions_sub,['sk','cs','en'])

# %%
f1_score(y_val, predictions_sub,average='weighted')
# Out:
# 0.8456072917343868
